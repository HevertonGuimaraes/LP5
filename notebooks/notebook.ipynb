# %% [markdown]
# # Aprendendo notebooks
#
# Introdução ao uso de notebooks e da biblioteca pandas.

# %%
nome = 'Luciano'

print(nome)

# %%
# Dicionários Python

aluno = {
    'nome':'Luciano',
    'matricula':'1234',
    'data_nascimento':'1993-09-05'
}

aluno2 = {
    'nome':'Cleitinho',
    'matricula':'5678',
    'data_nascimento':'2003-05-19'
}

print(aluno)
print(type(aluno))
print(aluno2['matricula'])

# %%
alunos = [{
    'nome':'Luciano',
    'matricula':'1234',
    'data_nascimento':'1993-09-05'
},

{
    'nome':'Cleitinho',
    'matricula':'5678',
    'data_nascimento':'2003-05-19'
}]

print(alunos[1]['nome'])

# %%
frutas = [
{
    'nomes':['uva', 'laranja', 'maça', 'abacaxi'],
    'quantidade':[10, 15, 100, 0],
    'valor':[10.45, 5.49, 7.43, 5]
}
]

print(f'Fruta: {frutas[0]['nomes'][1]}, Quantidade: {frutas[0]['quantidade'][1]}, Valor: {frutas[0]['valor'][1]}')

# %% [markdown]
# ## Instalando bibliotecas no Python
#
# Instala-se biblioteca python usando a estrutura:
#
# `pip install nome_biblioteca`

# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-3.0.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.4-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\adm\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\adm\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp312-cp312-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 4.2 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.7 MB 3.8 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/9.7 MB 3.9 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/9.7 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.7 MB 4.0 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.7 MB 4.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.7 MB 4.0 MB/s eta 0:00:02
#    -------------------------- ------------- 6.6/9.7 MB 4.0 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.7 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.4/9.7 MB 4.0 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.7 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 3.9 MB/s eta 0:00:00
# Downloading numpy-2.4.4-cp312-cp312-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.3 MB 4.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/12.3 MB 4.4 MB/s eta 0:00:03
#    -------- ------------------------------- 2.6/12.3 MB 4.2 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.4/12.3 MB 4.3 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.3 MB 4.3 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.3 MB 4.2 MB/s eta 0:00:02
#    -------------------- ------------------- 6.3/12.3 MB 4.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.3 MB 4.2 MB/s eta 0:00:02
#    ------------------------- -------------- 7.9/12.3 MB 4.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.3 MB 4.2 MB/s eta 0:00:01
#    ------------------------------- -------- 9.7/12.3 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.5/12.3 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 4.0 MB/s eta 0:00:00
# Downloading tzdata-2026.1-py2.py3-none-any.whl (348 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.4.4 pandas-3.0.2 tzdata-2026.1
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\ADM\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
frutas2 = ['uva', 'maça', 'laranja']

frutas3 = pd.Series(['uva', 'maça', 'laranja'])

print(type(frutas2))
print(type(frutas3))

# %%
# Serie (colunas)

display(frutas3)

# %%
# DataFrame

df = pd.DataFrame({
    'nome': ['uva', 'maça','laranja'],
    'quantidade': [10, 15, 20],
    'valor': [5.99, 3.50, 1.50],
    'data': ['2026-01-12','2026-02-06', '2025-03-15']
})

display(df)

# %%
display(df['data'])
